# %%
import pandas as pd
import matplotlib.pyplot as plt

# Reading file
wdiw_data = pd.read_excel('WDIW dataset.xlsx')
wdiw_meta=pd.read_excel('WDI_Metadata.xlsx')

#Filtering out everything except the 'Hot Rod' values.
wdiw_hr = wdiw_data.loc[wdiw_data['Cool Name'] == 'Hot Rod']

#Calculating missing values
missing_values = wdiw_hr.isnull().sum().sum()
print(missing_values)

#All the medians
wdiw_median = wdiw_hr.iloc[:, 4:].median()

#All the means
wdiw_mean = wdiw_hr.iloc[:, 4:].mean().round(2)

import pandas as pd
import matplotlib.pyplot as plt

# Reading file
wdiw_data = pd.read_excel('WDIW dataset.xlsx')
wdiw_meta=pd.read_excel('WDI_Metadata.xlsx')

#Filtering out everything except the 'Hot Rod' values.
wdiw_hr = wdiw_data.loc[wdiw_data['Cool Name'] == 'Hot Rod']

#Calculating missing values
missing_values = wdiw_hr.isnull().sum().sum()
print(missing_values)

#All the medians
wdiw_median = wdiw_hr.iloc[:, 4:].median()

#All the means
wdiw_mean = wdiw_hr.iloc[:, 4:].mean().round(2)

#All descriptive data

col=wdiw_hr.columns
info=wdiw_hr.info
desc=wdiw_hr.describe()

count=11
#Look for our variables 

print(wdiw_hr['Access to electricity (% of population)'].describe())
print(wdiw_hr['Access to electricity, rural (% of rural population)'].describe())
print(wdiw_hr['Access to electricity, urban (% of urban population)'].describe())
#Missing values in agriculture
print(wdiw_hr["Agriculture, forestry, and fishing, value added (% of GDP)"].describe())
print(wdiw_hr.loc[wdiw_hr["Agriculture, forestry, and fishing, value added (% of GDP)"].isnull(),'Country Name'])


#Missing values
print(wdiw_hr['Armed forces personnel (% of total labor force)'].describe())
#Missing values
print(wdiw_hr['Employment in agriculture (% of total employment) (modeled ILO estimate)'].describe())
#Missing values
print(wdiw_hr['Employment in industry (% of total employment) (modeled ILO estimate)'].describe())
#Missing values, wrong statistics
print(wdiw_hr['Employment in services (% of total employment) (modeled ILO estimate)'].describe())
#Missing values
print(wdiw_hr['GDP (current US$)'].describe(),format'.8f')

#Missing values
print(wdiw_hr['GDP growth (annual %)'].describe())
#Missing values
print(wdiw_hr["Industry (including construction), value added (% of GDP)"].describe())
#Missing values
print(wdiw_hr['Merchandise trade (% of GDP)'].describe())
#Missing values
print(wdiw_hr['Military expenditure (% of GDP)'].describe())
print(wdiw_hr['Population density (people per sq. km of land area)'].describe())
#Missing values
print(wdiw_hr['Population in the largest city (% of urban population)'].describe())
print(wdiw_hr['Population living in slums (% of urban population)'].describe())
#Missing values
print(wdiw_hr['Rural population (% of total population)'].describe())
#Missing values
print(wdiw_hr["Services, value added (% of GDP)"].describe())
#missing values, we can added it I think surface area hasn't changed, worng data
print(wdiw_hr['Surface area (sq. km)'].describe().round(2))
#Missing values
print(wdiw_hr['Tax revenue (% of GDP)'].describe())
print(wdiw_hr['Urban population (% of total population)'].describe())
print(wdiw_hr['Urban population growth (annual %)'].describe())

#if wdiw_meta['Indicator Name']=='Urban population growth (annual %)':
     # print(wdiw_meta['Long definition'])
# Out:
# 231
# 231
# count     11.000000
# mean      96.719218
# std        5.361171
# min       86.500000
# 25%       95.776608
# 50%       99.600000
# 75%      100.000000
# max      100.000000
# Name: Access to electricity (% of population), dtype: float64
# count     11.000000
# mean      93.351500
# std       11.905274
# min       68.488026
# 25%       93.831336
# 50%      100.000000
# 75%      100.000000
# max      100.000000
# Name: Access to electricity, rural (% of rural population), dtype: float64
# count     11.000000
# mean      99.236986
# std        1.063380
# min       97.149033
# 25%       98.507294
# 50%       99.843231
# 75%      100.000000
# max      100.000000
# Name: Access to electricity, urban (% of urban population), dtype: float64
# count     9.000000
# mean      7.279475
# std       5.025859
# min       0.916479
# 25%       3.380990
# 50%       5.042047
# 75%      10.829349
# max      15.072118
# Name: Agriculture, forestry, and fishing, value added (% of GDP), dtype: float64
# 21    Bermuda
# 34     Canada
# Name: Country Name, dtype: object
# count    10.000000
# mean      0.775670
# std       0.404324
# min       0.357811
# 25%       0.460178
# 50%       0.615921
# 75%       1.069619
# max       1.489588
# Name: Armed forces personnel (% of total labor force), dtype: float64
# count    10.000000
# mean     17.184500
# std      11.057003
# min       1.435000
# 25%      12.714500
# 50%      16.113500
# 75%      26.630750
# max      31.985001
# Name: Employment in agriculture (% of total employment) (modeled ILO estimate), dtype: float64
# count    10.000000
# mean     19.733200
# std       3.036733
# min      14.657000
# 25%      18.474751
# 50%      19.628500
# 75%      20.844251
# max      26.013000
# Name: Employment in industry (% of total employment) (modeled ILO estimate), dtype: float64
# count    10.000000
# mean     63.082401
# std      11.235223
# min      47.332001
# 25%      53.862501
# 50%      63.913000
# 75%      68.629751
# max      78.955002
# Name: Employment in services (% of total employment) (modeled ILO estimate), dtype: float64
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-300-bfb802ec6a0f> in <module>
#      65 print(wdiw_hr['Employment in services (% of total employment) (modeled ILO estimate)'].describe())
#      66 #Missing values
# ---> 67 print.format(wdiw_hr['GDP (current US$)'].describe(),'.8f')
#      68
#      69 #Missing values
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'format'
